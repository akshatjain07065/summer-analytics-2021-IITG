# %%
import pandas as pd

# %%
train_data = pd.read_csv("E:/akshat extras/iitg data analytics/week6/Train_Data.csv")
test_data = pd.read_csv("E:/akshat extras/iitg data analytics/week6/Test_Data.csv")

# %%
train_data
# Out:
#             date    campaign    adgroup     ad  impressions  clicks  cost  \
# 0     01-08-2020  campaign 1  adgroup 1   ad 1           24       6  0.08
# 1     01-08-2020  campaign 1  adgroup 2   ad 1            1       0  0.00
# 2     01-08-2020  campaign 1  adgroup 3   ad 1           13       4  0.04
# 3     01-08-2020  campaign 1  adgroup 4   ad 1            5       4  0.08
# 4     01-08-2020  campaign 1  adgroup 1   ad 2          247     126  1.29
# ...          ...         ...        ...    ...          ...     ...   ...
# 4566  28-02-2021  campaign 1  adgroup 3  ad 55           19       6  0.07
# 4567  28-02-2021  campaign 1  adgroup 4  ad 55            1       0  0.00
# 4568  28-02-2021  campaign 1  adgroup 3  ad 56           16       8  0.12
# 4569  28-02-2021  campaign 1  adgroup 1  ad 56           37      13  0.23
# 4570  28-02-2021  campaign 1  adgroup 1  ad 55           19      10  0.14
#
#       conversions  revenue
# 0               0     0.00
# ...

# %%
test_data
# Out:
#            date    campaign    adgroup     ad  cost  impressions  clicks  \
# 0    01-03-2021  campaign 1  adgroup 1   ad 1  0.58          121      49
# 1    01-03-2021  campaign 1  adgroup 3   ad 1  0.17           22      12
# 2    01-03-2021  campaign 1  adgroup 4   ad 1  0.05            5       3
# 3    01-03-2021  campaign 1  adgroup 2   ad 1  0.01            2       1
# 4    01-03-2021  campaign 1  adgroup 2   ad 2  0.01            3       1
# ..          ...         ...        ...    ...   ...          ...     ...
# 313  15-03-2021  campaign 1  adgroup 4  ad 55  0.01            1       1
# 314  15-03-2021  campaign 1  adgroup 3  ad 55  0.01            5       1
# 315  15-03-2021  campaign 1  adgroup 1  ad 55  0.14           25      11
# 316  15-03-2021  campaign 1  adgroup 3  ad 56  0.06            9       4
# 317  15-03-2021  campaign 1  adgroup 1  ad 56  0.33           67      27
#
#      conversions
# 0              1
# 1              0
# 2              0
# 3              0
# ...

# %%
train_data = train_data.drop(['date','campaign'], axis=1)
test_data = test_data.drop(['date','campaign'], axis=1)

# %%
train_data
# Out:
#         adgroup     ad  impressions  clicks  cost  conversions  revenue
# 0     adgroup 1   ad 1           24       6  0.08            0     0.00
# 1     adgroup 2   ad 1            1       0  0.00            0     0.00
# 2     adgroup 3   ad 1           13       4  0.04            0     0.00
# 3     adgroup 4   ad 1            5       4  0.08            0     0.00
# 4     adgroup 1   ad 2          247     126  1.29            4   925.71
# ...         ...    ...          ...     ...   ...          ...      ...
# 4566  adgroup 3  ad 55           19       6  0.07            0     0.00
# 4567  adgroup 4  ad 55            1       0  0.00            0     0.00
# 4568  adgroup 3  ad 56           16       8  0.12            1    93.20
# 4569  adgroup 1  ad 56           37      13  0.23            0     0.00
# 4570  adgroup 1  ad 55           19      10  0.14            0     0.00
#
# [4571 rows x 7 columns]

# %%
test_data
# Out:
#        adgroup     ad  cost  impressions  clicks  conversions
# 0    adgroup 1   ad 1  0.58          121      49            1
# 1    adgroup 3   ad 1  0.17           22      12            0
# 2    adgroup 4   ad 1  0.05            5       3            0
# 3    adgroup 2   ad 1  0.01            2       1            0
# 4    adgroup 2   ad 2  0.01            3       1            0
# ..         ...    ...   ...          ...     ...          ...
# 313  adgroup 4  ad 55  0.01            1       1            0
# 314  adgroup 3  ad 55  0.01            5       1            0
# 315  adgroup 1  ad 55  0.14           25      11            0
# 316  adgroup 3  ad 56  0.06            9       4            0
# 317  adgroup 1  ad 56  0.33           67      27            1
#
# [318 rows x 6 columns]

# %%
# df_encoded=pd.get_dummies(train_data,columns='adgroup')
# df_encoded

# %%
#df_cat = train_data.select_dtypes(include="object").columns.values
# df_encoded=pd.get_dummies(train_data,columns=['adgroup'])

# %%
# df_cat

# %%
# df_encoded

# %%
X_train = train_data.drop(['revenue'], axis=1)

# %%
X_train
# Out:
#         adgroup     ad  impressions  clicks  cost  conversions
# 0     adgroup 1   ad 1           24       6  0.08            0
# 1     adgroup 2   ad 1            1       0  0.00            0
# 2     adgroup 3   ad 1           13       4  0.04            0
# 3     adgroup 4   ad 1            5       4  0.08            0
# 4     adgroup 1   ad 2          247     126  1.29            4
# ...         ...    ...          ...     ...   ...          ...
# 4566  adgroup 3  ad 55           19       6  0.07            0
# 4567  adgroup 4  ad 55            1       0  0.00            0
# 4568  adgroup 3  ad 56           16       8  0.12            1
# 4569  adgroup 1  ad 56           37      13  0.23            0
# 4570  adgroup 1  ad 55           19      10  0.14            0
#
# [4571 rows x 6 columns]

# %%
# df_encoded1=pd.get_dummies(test_data,columns=['adgroup'])

# %%
# df_encoded1

# %%
X_test = test_data
X_test
# Out:
#        adgroup     ad  cost  impressions  clicks  conversions
# 0    adgroup 1   ad 1  0.58          121      49            1
# 1    adgroup 3   ad 1  0.17           22      12            0
# 2    adgroup 4   ad 1  0.05            5       3            0
# 3    adgroup 2   ad 1  0.01            2       1            0
# 4    adgroup 2   ad 2  0.01            3       1            0
# ..         ...    ...   ...          ...     ...          ...
# 313  adgroup 4  ad 55  0.01            1       1            0
# 314  adgroup 3  ad 55  0.01            5       1            0
# 315  adgroup 1  ad 55  0.14           25      11            0
# 316  adgroup 3  ad 56  0.06            9       4            0
# 317  adgroup 1  ad 56  0.33           67      27            1
#
# [318 rows x 6 columns]

# %%
# df_encoded1.dtypes

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# X_train["adgroup"] = le.fit_transform(X_train["adgroup"])
# X_train
# X_train.dtypes

# %%
X_train
# Out:
#         adgroup     ad  impressions  clicks  cost  conversions
# 0     adgroup 1   ad 1           24       6  0.08            0
# 1     adgroup 2   ad 1            1       0  0.00            0
# 2     adgroup 3   ad 1           13       4  0.04            0
# 3     adgroup 4   ad 1            5       4  0.08            0
# 4     adgroup 1   ad 2          247     126  1.29            4
# ...         ...    ...          ...     ...   ...          ...
# 4566  adgroup 3  ad 55           19       6  0.07            0
# 4567  adgroup 4  ad 55            1       0  0.00            0
# 4568  adgroup 3  ad 56           16       8  0.12            1
# 4569  adgroup 1  ad 56           37      13  0.23            0
# 4570  adgroup 1  ad 55           19      10  0.14            0
#
# [4571 rows x 6 columns]

# %%
X_train = X_train.drop(['ad'], axis=1)

# %%
# from sklearn import preprocessing
# le = preprocessing.LabelEncoder()
# X_test["adgroup"] = le.fit_transform(X_test["adgroup"])
# X_test
# X_test.dtypes

# %%
y_train = train_data.loc[:, train_data.columns == 'revenue'] #select all columns but not the labels
y_train
# Out:
#       revenue
# 0        0.00
# 1        0.00
# 2        0.00
# 3        0.00
# 4      925.71
# ...       ...
# 4566     0.00
# 4567     0.00
# 4568    93.20
# 4569     0.00
# 4570     0.00
#
# [4571 rows x 1 columns]

# %%
X_test = X_test[X_train.columns]

# %%
X_test
X_test = X_test.drop(['ad'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-236-b9956c08131b> in <module>
#       1 X_test
# ----> 2 X_test = X_test.drop(['ad'], axis=1)
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
# ...

# %%
# X_train
# X_train = X_train.drop(['cost'], axis=1)
# X_test
# X_test = X_test.drop(['cost'], axis=1)

# %%
X_test
# Out:
#        adgroup  impressions  clicks  cost  conversions
# 0    adgroup 1          121      49  0.58            1
# 1    adgroup 3           22      12  0.17            0
# 2    adgroup 4            5       3  0.05            0
# 3    adgroup 2            2       1  0.01            0
# 4    adgroup 2            3       1  0.01            0
# ..         ...          ...     ...   ...          ...
# 313  adgroup 4            1       1  0.01            0
# 314  adgroup 3            5       1  0.01            0
# 315  adgroup 1           25      11  0.14            0
# 316  adgroup 3            9       4  0.06            0
# 317  adgroup 1           67      27  0.33            1
#
# [318 rows x 5 columns]

# %%
X_test = X_test.drop(['adgroup'], axis=1)
X_test
# Out:
#      impressions  clicks  cost  conversions
# 0            121      49  0.58            1
# 1             22      12  0.17            0
# 2              5       3  0.05            0
# 3              2       1  0.01            0
# 4              3       1  0.01            0
# ..           ...     ...   ...          ...
# 313            1       1  0.01            0
# 314            5       1  0.01            0
# 315           25      11  0.14            0
# 316            9       4  0.06            0
# 317           67      27  0.33            1
#
# [318 rows x 4 columns]

# %%
X_train = X_train.drop(['adgroup'], axis=1)
X_train
# Out:
#       impressions  clicks  cost  conversions
# 0              24       6  0.08            0
# 1               1       0  0.00            0
# 2              13       4  0.04            0
# 3               5       4  0.08            0
# 4             247     126  1.29            4
# ...           ...     ...   ...          ...
# 4566           19       6  0.07            0
# 4567            1       0  0.00            0
# 4568           16       8  0.12            1
# 4569           37      13  0.23            0
# 4570           19      10  0.14            0
#
# [4571 rows x 4 columns]

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled= scaler.fit_transform(X_train)
X_test_scaled= scaler.transform(X_test)

# %%
X_train
# Out:
#       impressions  clicks  cost  conversions
# 0              24       6  0.08            0
# 1               1       0  0.00            0
# 2              13       4  0.04            0
# 3               5       4  0.08            0
# 4             247     126  1.29            4
# ...           ...     ...   ...          ...
# 4566           19       6  0.07            0
# 4567            1       0  0.00            0
# 4568           16       8  0.12            1
# 4569           37      13  0.23            0
# 4570           19      10  0.14            0
#
# [4571 rows x 4 columns]

# %%
# from sklearn.preprocessing import PowerTransformer

# pt = PowerTransformer(method='box-cox')
# X_train_scaled = pt.fit_transform(X_train)
# X_test_scaled = pt.transform(X_test)

# %%
import numpy as np
def score(model, title = "Default"):
    model.fit(X_train_scaled, y_train)
    preds = model.predict(X_test_scaled)
#     print(confusion_matrix(y_test, preds))
    #print(preds)
    df = pd.DataFrame(preds, columns = ['revenue'])
    df[df < 10] = 0

#     df['revenue'] = np.where(X_test['conversions']==0,0, df['revenue'])

    print(df)
    df.to_csv('raw_data24.csv', index=False)

# %%
from sklearn.svm import SVR
clf_svm = SVR(C = 50, gamma = 0.42, kernel = 'rbf')
score (clf_svm,"svm")
# Out:
# c:\users\lenovo\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
#         revenue
# 0    106.981105
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# ..          ...
# 313    0.000000
# 314    0.000000
# 315    0.000000
# 316    0.000000
# 317  109.664202
#
# [318 rows x 1 columns]

# %%
# from sklearn.linear_model import LinearRegression

# clf3=LinearRegression()
# score(clf3,"LR")

# %%
# from sklearn.linear_model import Ridge

# clf3=Ridge()
# score(clf3,"LR")

# %%
# from sklearn.linear_model import Lasso

# clf3=Lasso()
# score(clf3,"LR")

# %%
# #Using Decision Tree Regressor to Predict the Doctor Fees
# #importing the library for Decision Tree Regressor
# from sklearn.tree import DecisionTreeRegressor

# #Initializing the Deision Tree Regressor
# dtr = DecisionTreeRegressor()

# # Fitting the Decision Tree Regressor with training Data
# dtr.fit(X_train,y_train)

# # Predicting the values(Fees) for Test Data
# Y_pred_dtr = scaler.inverse_transform(dtr.predict(X_test))
# """NOTE:scaler.inverse_transform is used to inverse the scaling"""

# # Saving the Predicted values in to an Excel file
# pd.DataFrame(Y_pred_dtr, columns = ['revenue']).to_excel("predictions_tree.csv", index = False)

# %%
# # Fitting Decision Tree Regression to the dataset
# from sklearn.tree import DecisionTreeRegressor
# regressor = DecisionTreeRegressor()
# regressor.fit(X_train_scaled, y_train)

# %%
# y_pred = regressor.predict(X_test_scaled)
# y_pred

# %%
# df = pd.DataFrame(y_pred, columns = ['revenue'])
# df[df < 10] = 0

# df['revenue'] = np.where(X_test['conversions']==0,0, df['revenue'])

# print(df)
# df.to_csv('raw_data24.csv', index=False)
